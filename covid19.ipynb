# %%
import numpy as np
import pandas as pd
import os
import urllib
# %matplotlib inline

# %%
df=pd.read_csv('data/covid/WHO-COVID-19-global-data.csv')

# %%
df
# Out:
#       Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0        2020-02-24            AF  Afghanistan        EMRO           1
# 1        2020-02-25            AF  Afghanistan        EMRO           0
# 2        2020-02-26            AF  Afghanistan        EMRO           0
# 3        2020-02-27            AF  Afghanistan        EMRO           0
# 4        2020-02-28            AF  Afghanistan        EMRO           0
# ...             ...           ...          ...         ...         ...
# 29650    2020-07-17            ZW     Zimbabwe        AFRO         273
# 29651    2020-07-18            ZW     Zimbabwe        AFRO          58
# 29652    2020-07-19            ZW     Zimbabwe        AFRO          58
# 29653    2020-07-20            ZW     Zimbabwe        AFRO         133
# 29654    2020-07-21            ZW     Zimbabwe        AFRO         102
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# ...

# %%
df_index=df.index
df_index
# Out:
# RangeIndex(start=0, stop=29655, step=1)

# %%
df_cols=df.columns
df_cols
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([    0,     1,     2, ..., 29652, 29653, 29654], dtype=int64)

# %%
df.values
# Out:
# array([['2020-02-24', 'AF', 'Afghanistan', ..., 1, 0, 0],
#        ['2020-02-25', 'AF', 'Afghanistan', ..., 1, 0, 0],
#        ['2020-02-26', 'AF', 'Afghanistan', ..., 1, 0, 0],
#        ...,
#        ['2020-07-19', 'ZW', 'Zimbabwe', ..., 1478, 1, 25],
#        ['2020-07-20', 'ZW', 'Zimbabwe', ..., 1611, 0, 25],
#        ['2020-07-21', 'ZW', 'Zimbabwe', ..., 1713, 1, 26]], dtype=object)

# %%
df.shape
# Out:
# (29655, 8)

# %%
df.head()
# Out:
#   Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0    2020-02-24            AF  Afghanistan        EMRO           1
# 1    2020-02-25            AF  Afghanistan        EMRO           0
# 2    2020-02-26            AF  Afghanistan        EMRO           0
# 3    2020-02-27            AF  Afghanistan        EMRO           0
# 4    2020-02-28            AF  Afghanistan        EMRO           0
#
#     Cumulative_cases   New_deaths   Cumulative_deaths
# 0                  1            0                   0
# 1                  1            0                   0
# 2                  1            0                   0
# 3                  1            0                   0
# 4                  1            0                   0

# %%
df.tail()
# Out:
#       Date_reported  Country_code   Country  WHO_region   New_cases  \
# 29650    2020-07-17            ZW  Zimbabwe        AFRO         273
# 29651    2020-07-18            ZW  Zimbabwe        AFRO          58
# 29652    2020-07-19            ZW  Zimbabwe        AFRO          58
# 29653    2020-07-20            ZW  Zimbabwe        AFRO         133
# 29654    2020-07-21            ZW  Zimbabwe        AFRO         102
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# 29650               1362            3                  23
# 29651               1420            1                  24
# 29652               1478            1                  25
# 29653               1611            0                  25
# 29654               1713            1                  26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29655 entries, 0 to 29654
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date_reported       29655 non-null  object
#  1    Country_code       29525 non-null  object
#  2    Country            29655 non-null  object
#  3    WHO_region         29655 non-null  object
#  4    New_cases          29655 non-null  int64
#  5    Cumulative_cases   29655 non-null  int64
#  6    New_deaths         29655 non-null  int64
#  7    Cumulative_deaths  29655 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#           New_cases   Cumulative_cases    New_deaths   Cumulative_deaths
# count  29655.000000       2.965500e+04  29655.000000        29655.000000
# mean     490.240904       2.375698e+04     20.480796         1295.601787
# std     2897.817256       1.402746e+05    125.154056         7425.461000
# min   -29726.000000       1.000000e+00   -514.000000            0.000000
# 25%        0.000000       3.900000e+01      0.000000            0.000000
# 50%        6.000000       5.210000e+02      0.000000           10.000000
# 75%      100.000000       4.863500e+03      2.000000          104.000000
# max    74354.000000       3.748248e+06   6409.000000       139964.000000

# %%
df[" Country"]
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 29650       Zimbabwe
# 29651       Zimbabwe
# 29652       Zimbabwe
# 29653       Zimbabwe
# 29654       Zimbabwe
# Name:  Country, Length: 29655, dtype: object

# %%
df[" Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Costa Rica', 'Côte d’Ivoire', 'Croatia',
#        'Cuba', 'Curacao', 'Cyprus', 'Czechia',
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df.columns=[col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.Country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 29650       Zimbabwe
# 29651       Zimbabwe
# 29652       Zimbabwe
# 29653       Zimbabwe
# 29654       Zimbabwe
# Name: Country, Length: 29655, dtype: object

# %%
df.loc[1:4, 'Country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8,['Country','New_cases']]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country=='Nepal'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29650    False
# 29651    False
# 29652    False
# 29653    False
# 29654    False
# Name: Country, Length: 29655, dtype: bool

# %%
df[df.Country=='Nepal']
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 18784    2020-01-23           NP   Nepal      SEARO          1
# 18785    2020-01-24           NP   Nepal      SEARO          0
# 18786    2020-01-25           NP   Nepal      SEARO          0
# 18787    2020-01-26           NP   Nepal      SEARO          0
# 18788    2020-01-27           NP   Nepal      SEARO          0
# ...             ...          ...     ...        ...        ...
# 18960    2020-07-17           NP   Nepal      SEARO        167
# 18961    2020-07-18           NP   Nepal      SEARO        101
# 18962    2020-07-19           NP   Nepal      SEARO         57
# 18963    2020-07-20           NP   Nepal      SEARO        156
# 18964    2020-07-21           NP   Nepal      SEARO        186
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 18784                 1           0                  0
# 18785                 1           0                  0
# ...

# %%
df[df.New_deaths>1000]
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 3761     2020-05-21           BR                    Brazil       AMRO
# 3763     2020-05-23           BR                    Brazil       AMRO
# 3764     2020-05-24           BR                    Brazil       AMRO
# 3768     2020-05-28           BR                    Brazil       AMRO
# 3769     2020-05-29           BR                    Brazil       AMRO
# ...             ...          ...                       ...        ...
# 28557    2020-06-04           US  United States of America       AMRO
# 28559    2020-06-06           US  United States of America       AMRO
# 28560    2020-06-07           US  United States of America       AMRO
# 28564    2020-06-11           US  United States of America       AMRO
# 28580    2020-06-27           US  United States of America       AMRO
#
#        New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df.loc[df.New_deaths>1000, ['New_deaths', 'Country']]
# Out:
#        New_deaths                   Country
# 3761         1179                    Brazil
# 3763         1188                    Brazil
# 3764         1001                    Brazil
# 3768         1039                    Brazil
# 3769         1086                    Brazil
# ...           ...                       ...
# 28557        1043  United States of America
# 28559        1035  United States of America
# 28560        1127  United States of America
# 28564        1208  United States of America
# 28580        2516  United States of America
#
# [110 rows x 2 columns]

# %%
df.loc[(df.New_deaths>0) & (df.Country_code=='NP'),['Date_reported', 'Country', 'New_cases', 'New_deaths', 'Cumulative_cases', 'Cumulative_deaths']]
# Out:
#       Date_reported Country  New_cases  New_deaths  Cumulative_cases  \
# 18898    2020-05-16   Nepal         23           1               281
# 18899    2020-05-17   Nepal         14           1               295
# 18903    2020-05-21   Nepal         27           1               454
# 18907    2020-05-25   Nepal         79           1               682
# 18910    2020-05-28   Nepal        156           1              1042
# 18911    2020-05-29   Nepal        170           1              1212
# 18913    2020-05-31   Nepal        171           2              1572
# 18917    2020-06-04   Nepal        201           1              2300
# 18918    2020-06-05   Nepal        334           1              2634
# 18919    2020-06-06   Nepal        278           1              2912
# 18920    2020-06-07   Nepal        323           2              3235
# 18922    2020-06-09   Nepal        314           1              3762
# 18923    2020-06-10   Nepal        323           1              4085
# ...

# %%
df.loc[df.Country_code=='NP',['New_cases']].max()
# Out:
# New_cases    740
# dtype: int64

# %%
df.loc[df.Country_code=='NP',['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code=='NP',['New_cases']].sum()
# Out:
# New_cases    17844
# dtype: int64

# %%
df.loc[df.Country_code=='NP',['Cumulative_cases']].max()
# Out:
# Cumulative_cases    17844
# dtype: int64

# %%
df.New_cases.idxmax()
# Out:
# 28602

# %%
df.loc[df.New_cases.idxmax(),['Date_reported', 'Country', 'New_cases', 'New_deaths']]
# Out:
# Date_reported                  2020-07-19
# Country          United States of America
# New_cases                           74354
# New_deaths                            917
# Name: 28602, dtype: object

# %%
df[df.New_cases<0]
# Out:
#       Date_reported Country_code  \
# 2856     2020-05-19           BJ
# 6793     2020-06-27           CW
# 7828     2020-05-07           EC
# 7831     2020-05-10           EC
# 7833     2020-05-12           EC
# 9521     2020-06-03           FR
# 9543     2020-06-25           FR
# 12300    2020-05-14           HN
# 13621    2020-05-18           IL
# 13828    2020-06-20           IT
# 15260    2020-03-23           LV
# 15867    2020-03-25           LI
# 16009    2020-03-23           LT
# 16046    2020-04-29           LT
# 16151    2020-03-23           LU
# 16320    2020-05-09           MG
# 17772    2020-03-30           MC
# 18026    2020-03-24           ME
# 18990    2020-03-23           NL
# 20062    2020-03-23           NO
# 20261    2020-05-23           PS
# 21690    2020-05-03           PT
# 22460    2020-06-17           RE
# 23885    2020-05-08           ST
# 23887    2020-05-10           ST
# 23896    2020-05-19           ST
# 23903    2020-05-26           ST
# ...

# %%
df['pct_cases']=(df['New_cases']/df['Cumulative_cases'])*100
df['pct_cases']
# Out:
# 0        100.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
#             ...
# 29650     20.044053
# 29651      4.084507
# 29652      3.924222
# 29653      8.255742
# 29654      5.954466
# Name: pct_cases, Length: 29655, dtype: float64
